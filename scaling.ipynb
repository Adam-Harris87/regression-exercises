# %%
import sklearn.preprocessing
import pandas as pd
import numpy as np
import wrangle as w
import matplotlib.pyplot as plt

# %%
train, val, test = w.wrangle_zillow()
# Out:
# opening data from local file

# %%
train.shape, val.shape, test.shape
# Out:
# ((1038959, 7), (445269, 7), (371057, 7))

# %%
cols = ['area', 'tax_value', 'taxamount']

# %%
train['area'].values.reshape(-1,1)
# Out:
# array([[1561.],
#        [1770.],
#        [1452.],
#        ...,
#        [2132.],
#        [ 780.],
#        [1132.]])

# %% [markdown]
# # 1. Apply the scalers we talked about in this lesson to your data and visualize the results for the unscaled and scaled distribution .

# %%
# for col in cols:
scaler = sklearn.preprocessing.MinMaxScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['area'].values.reshape(-1,1))

area_train_scaled = scaler.transform(train['area'].values.reshape(-1,1))
area_validate_scaled = scaler.transform(val['area'].values.reshape(-1,1))
area_test_scaled = scaler.transform(test['area'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(221)
plt.hist(train['area'], bins=25, ec='black')
plt.title('area Original')
plt.subplot(222)
plt.hist(area_train_scaled, bins=25, ec='black')
plt.title('area MinMaxScaler Scaled')

scaler = sklearn.preprocessing.StandardScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['area'].values.reshape(-1,1))

area_train_scaled = scaler.transform(train['area'].values.reshape(-1,1))
area_validate_scaled = scaler.transform(val['area'].values.reshape(-1,1))
area_test_scaled = scaler.transform(test['area'].values.reshape(-1,1))

# plt.figure(figsize=(13, 6))
# plt.subplot(121)
# plt.hist(train['area'], bins=25, ec='black')
# plt.title('area Original')
plt.subplot(223)
plt.hist(area_train_scaled, bins=25, ec='black')
plt.title('area StandardScaler Scaled')
# plt.show()


scaler = sklearn.preprocessing.RobustScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['area'].values.reshape(-1,1))

area_train_scaled = scaler.transform(train['area'].values.reshape(-1,1))
area_validate_scaled = scaler.transform(val['area'].values.reshape(-1,1))
area_test_scaled = scaler.transform(test['area'].values.reshape(-1,1))

# plt.figure(figsize=(13, 6))
# plt.subplot(121)
# plt.hist(train['area'], bins=25, ec='black')
# plt.title('area Original')
plt.subplot(224)
plt.hist(area_train_scaled, bins=25, ec='black')
plt.title('area RobustScaler Scaled')
plt.show()

# %%
# for col in cols:
scaler = sklearn.preprocessing.MinMaxScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['tax_value'].values.reshape(-1,1))

tax_value_train_scaled = scaler.transform(train['tax_value'].values.reshape(-1,1))
tax_value_validate_scaled = scaler.transform(val['tax_value'].values.reshape(-1,1))
tax_value_test_scaled = scaler.transform(test['tax_value'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(221)
plt.hist(train['tax_value'], bins=25, ec='black')
plt.title('tax_value Original')
plt.subplot(222)
plt.hist(tax_value_train_scaled, bins=25, ec='black')
plt.title('tax_value MinMaxScaler Scaled')
# plt.show()

# for col in cols:
scaler = sklearn.preprocessing.StandardScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['tax_value'].values.reshape(-1,1))

tax_value_train_scaled = scaler.transform(train['tax_value'].values.reshape(-1,1))
tax_value_validate_scaled = scaler.transform(val['tax_value'].values.reshape(-1,1))
tax_value_test_scaled = scaler.transform(test['tax_value'].values.reshape(-1,1))

# plt.figure(figsize=(13, 6))
# plt.subplot(121)
# plt.hist(train['tax_value'], bins=25, ec='black')
# plt.title('tax_value Original')
plt.subplot(223)
plt.hist(tax_value_train_scaled, bins=25, ec='black')
plt.title('tax_value StandardScaler Scaled')
# plt.show()

# for col in cols:
scaler = sklearn.preprocessing.RobustScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['tax_value'].values.reshape(-1,1))

tax_value_train_scaled = scaler.transform(train['tax_value'].values.reshape(-1,1))
tax_value_validate_scaled = scaler.transform(val['tax_value'].values.reshape(-1,1))
tax_value_test_scaled = scaler.transform(test['tax_value'].values.reshape(-1,1))

# plt.figure(figsize=(13, 6))
# plt.subplot(121)
# plt.hist(train['tax_value'], bins=25, ec='black')
# plt.title('tax_value Original')
plt.subplot(224)
plt.hist(tax_value_train_scaled, bins=25, ec='black')
plt.title('tax_value RobustScaler Scaled')
plt.show()

# %%
# for col in cols:
scaler = sklearn.preprocessing.MinMaxScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['taxamount'].values.reshape(-1,1))

taxamount_train_scaled = scaler.transform(train['taxamount'].values.reshape(-1,1))
taxamount_validate_scaled = scaler.transform(val['taxamount'].values.reshape(-1,1))
taxamount_test_scaled = scaler.transform(test['taxamount'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(221)
plt.hist(train['taxamount'], bins=25, ec='black')
plt.title('taxamount Original')
plt.subplot(222)
plt.hist(taxamount_train_scaled, bins=25, ec='black')
plt.title('taxamount MinMaxScaler Scaled')
# plt.show()

# for col in cols:
scaler = sklearn.preprocessing.StandardScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['taxamount'].values.reshape(-1,1))

taxamount_train_scaled = scaler.transform(train['taxamount'].values.reshape(-1,1))
taxamount_validate_scaled = scaler.transform(val['taxamount'].values.reshape(-1,1))
taxamount_test_scaled = scaler.transform(test['taxamount'].values.reshape(-1,1))

# plt.figure(figsize=(13, 6))
# plt.subplot(121)
# plt.hist(train['taxamount'], bins=25, ec='black')
# plt.title('taxamount Original')
plt.subplot(223)
plt.hist(taxamount_train_scaled, bins=25, ec='black')
plt.title('taxamount StandardScaler Scaled')
# plt.show()

# for col in cols:
scaler = sklearn.preprocessing.RobustScaler()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['taxamount'].values.reshape(-1,1))

taxamount_train_scaled = scaler.transform(train['taxamount'].values.reshape(-1,1))
taxamount_validate_scaled = scaler.transform(val['taxamount'].values.reshape(-1,1))
taxamount_test_scaled = scaler.transform(test['taxamount'].values.reshape(-1,1))

# plt.figure(figsize=(13, 6))
# plt.subplot(121)
# plt.hist(train['taxamount'], bins=25, ec='black')
# plt.title('taxamount Original')
plt.subplot(224)
plt.hist(taxamount_train_scaled, bins=25, ec='black')
plt.title('taxamount RobustScaler Scaled')
plt.show()

# %% [markdown]
# # 2. Apply the .inverse_transform method to your scaled data. Is the resulting dataset the exact same as the original data?

# %%
inversed = pd.DataFrame(scaler.inverse_transform(taxamount_train_scaled))

# %%
tax = pd.DataFrame(train['taxamount'])

# %%
inversed.rename(columns={0:'taxamount'})
# Out:
#          taxamount
# 0          2504.40
# 1          1671.93
# 2          1310.88
# 3          1900.28
# 4          5315.27
# ...            ...
# 1038954    3282.40
# 1038955    1463.61
# 1038956    2037.38
# 1038957    6509.69
# 1038958    3563.75
#
# [1038959 rows x 1 columns]

# %%
plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(train['taxamount'], bins=25, ec='black')
plt.title('taxamount Original')
plt.subplot(122)
plt.hist(inversed, bins=25, ec='black')
plt.title('taxamount RobustScaler.inverse_transform Scaled')
plt.show()

# %% [markdown]
# yep

# %% [markdown]
# # 3. Read the documentation for sklearn's QuantileTransformer. Use normal for the output_distribution and apply this scaler to your data. Visualize the result of your data scaling.

# %%
scaler = sklearn.preprocessing.QuantileTransformer(output_distribution='normal')
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['area'].values.reshape(-1,1))

area_train_scaled = scaler.transform(train['area'].values.reshape(-1,1))
area_validate_scaled = scaler.transform(val['area'].values.reshape(-1,1))
area_test_scaled = scaler.transform(test['area'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(train['area'], bins=25, ec='black')
plt.title('area Original')
plt.subplot(122)
plt.hist(area_train_scaled, bins=25, ec='black')
plt.title('area QuantileTransformer Scaled')
plt.show()

# %%
scaler = sklearn.preprocessing.QuantileTransformer(output_distribution='normal')
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['tax_value'].values.reshape(-1,1))

tax_value_train_scaled = scaler.transform(train['tax_value'].values.reshape(-1,1))
tax_value_validate_scaled = scaler.transform(val['tax_value'].values.reshape(-1,1))
tax_value_test_scaled = scaler.transform(test['tax_value'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(train['tax_value'], bins=25, ec='black')
plt.title('tax_value Original')
plt.subplot(122)
plt.hist(tax_value_train_scaled, bins=25, ec='black')
plt.title('tax_value QuantileTransformer Scaled')
plt.show()

# %%
scaler = sklearn.preprocessing.QuantileTransformer(output_distribution='normal')
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['taxamount'].values.reshape(-1,1))

taxamount_train_scaled = scaler.transform(train['taxamount'].values.reshape(-1,1))
taxamount_validate_scaled = scaler.transform(val['taxamount'].values.reshape(-1,1))
taxamount_test_scaled = scaler.transform(test['taxamount'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(train['taxamount'], bins=25, ec='black')
plt.title('taxamount Original')
plt.subplot(122)
plt.hist(taxamount_train_scaled, bins=25, ec='black')
plt.title('taxamount QuantileTransformer Scaled')
plt.show()

# %% [markdown]
# # 4. Use the QuantileTransformer, but omit the output_distribution argument. Visualize your results. What do you notice?

# %%
scaler = sklearn.preprocessing.QuantileTransformer()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['area'].values.reshape(-1,1))

area_train_scaled = scaler.transform(train['area'].values.reshape(-1,1))
area_validate_scaled = scaler.transform(val['area'].values.reshape(-1,1))
area_test_scaled = scaler.transform(test['area'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(train['area'], bins=25, ec='black')
plt.title('area Original')
plt.subplot(122)
plt.hist(area_train_scaled, bins=25, ec='black')
plt.title('area QuantileTransformer Scaled')
plt.show()

# %%
scaler = sklearn.preprocessing.QuantileTransformer()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['tax_value'].values.reshape(-1,1))

tax_value_train_scaled = scaler.transform(train['tax_value'].values.reshape(-1,1))
tax_value_validate_scaled = scaler.transform(val['tax_value'].values.reshape(-1,1))
tax_value_test_scaled = scaler.transform(test['tax_value'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(train['tax_value'], bins=25, ec='black')
plt.title('tax_value Original')
plt.subplot(122)
plt.hist(tax_value_train_scaled, bins=25, ec='black')
plt.title('tax_value QuantileTransformer Scaled')
plt.show()

# %%
scaler = sklearn.preprocessing.QuantileTransformer()
# Note that we only call .fit with the training data,
# but we use .transform to apply the scaling to all the data splits.
scaler.fit(train['taxamount'].values.reshape(-1,1))

taxamount_train_scaled = scaler.transform(train['taxamount'].values.reshape(-1,1))
taxamount_validate_scaled = scaler.transform(val['taxamount'].values.reshape(-1,1))
taxamount_test_scaled = scaler.transform(test['taxamount'].values.reshape(-1,1))

plt.figure(figsize=(13, 6))
plt.subplot(121)
plt.hist(train['taxamount'], bins=25, ec='black')
plt.title('taxamount Original')
plt.subplot(122)
plt.hist(taxamount_train_scaled, bins=25, ec='black')
plt.title('taxamount QuantileTransformer Scaled')
plt.show()
